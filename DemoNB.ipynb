# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 6, 4]

plt.plot(x, y)
plt.xlabel('a - axis')
plt.ylabel('y - axis')
plt.title("Graph")

plt.savefig("demo_nb_images/graph_plot.png")
plt.show()

# %%
print("Hello World")
# Out:
# Hello World
