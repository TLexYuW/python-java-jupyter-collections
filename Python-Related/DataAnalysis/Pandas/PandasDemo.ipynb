# %% [markdown]
# # Import

# %%
import pandas as pd
import requests as rq
from IPython.display import display, HTML
display(HTML("<style>:root { --jp-notebook-max-width: 100% !important; }</style>"))
# Out:
# <style>:root { --jp-notebook-max-width: 100% !important; }</style>

# %% [markdown]
# ---

# %% [markdown]
# # TOC

# %% [markdown]
# - read_csv
# - read_json

# %% [markdown]
# ---

# %% [markdown]
# # Title

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# # Setup

# %%
# pd.set_option("display.max_columns", None)
# pd.set_option('display.max_colwidth', None)
# pd.set_option("display.max_rows", None)

# %% [markdown]
# ---

# %% [markdown]
# # read_csv

# %%
df = pd.read_csv('../../csv_datasets/s&p500_5yr.csv')
print(df)
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %% [markdown]
# ---

# %%
df = pd.read_csv('../../csv_datasets/s&p500_5yr.csv', index_col="date")
print(df.head())
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %% [markdown]
# ---

# %% [markdown]
# # read_json

# %%
pd.read_json('https://jsonplaceholder.typicode.com/comments')
# Out:
#      postId   id  \
# 0         1    1
# 1         1    2
# 2         1    3
# 3         1    4
# 4         1    5
# 5         2    6
# 6         2    7
# 7         2    8
# 8         2    9
# 9         2   10
# 10        3   11
# 11        3   12
# 12        3   13
# 13        3   14
# 14        3   15
# 15        4   16
# 16        4   17
# 17        4   18
# 18        4   19
# 19        4   20
# 20        5   21
# 21        5   22
# 22        5   23
# 23        5   24
# 24        5   25
# 25        6   26
# 26        6   27
# 27        6   28
# 28        6   29
# 29        6   30
# 30        7   31
# 31        7   32
# 32        7   33
# 33        7   34
# 34        7   35
# 35        8   36
# 36        8   37
# 37        8   38
# 38        8   39
# 39        8   40
# 40        9   41
# 41        9   42
# 42        9   43
# 43        9   44
# 44        9   45
# 45       10   46
# 46       10   47
# 47       10   48
# 48       10   49
# 49       10   50
# 50       11   51
# ...

# %%
pd.read_json('https://jsonplaceholder.typicode.com/comments').head()
# Out:
#    postId  id                                       name  \
# 0       1   1               id labore ex et quam laborum
# 1       1   2  quo vero reiciendis velit similique earum
# 2       1   3              odio adipisci rerum aut animi
# 3       1   4                             alias odio sit
# 4       1   5      vero eaque aliquid doloribus et culpa
#
#                     email  \
# 0      Eliseo@gardner.biz
# 1  Jayne_Kuhic@sydney.com
# 2     Nikita@garfield.biz
# 3           Lew@alysha.tv
# 4       Hayden@althea.biz
#
#                                                                                                                                                                                                                             body
# 0                                                                        laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium
# ...

# %%
pd.read_json('https://jsonplaceholder.typicode.com/comments').tail()
# Out:
#      postId   id                                                 name  \
# 495     100  496  et occaecati asperiores quas voluptas ipsam nostrum
# 496     100  497               doloribus dolores ut dolores occaecati
# 497     100  498                             dolores minus aut libero
# 498     100  499  excepturi sunt cum a et rerum quo voluptatibus quia
# 499     100  500                                   ex eaque eum natus
#
#                             email  \
# 495               Zola@lizzie.com
# 496             Dolly@mandy.co.uk
# 497             Davion@eldora.net
# 498  Wilburn_Labadie@araceli.name
# 499                Emma@joanny.ca
#
#                                                                                                                                                                     body
# 495         neque unde voluptatem iure\nodio excepturi ipsam ad id\nipsa sed expedita error quam\nvoluptatem tempora necessitatibus suscipit culpa veniam porro iste vel
# ...
