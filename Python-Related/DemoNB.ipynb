# %% [markdown]
# # Import Packages

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Matplotlib

# %%
x = [1, 2, 3]
y = [2, 6, 4]

plt.plot(x, y)
plt.xlabel("a - axis")
plt.ylabel("y - axis")
plt.title("Graph")

plt.savefig("../demo_nb_images/graph_plot.png")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Demo

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ---

# %% [markdown]
# # Template

# %%
# Template Code

# %% [markdown]
# ---

# %% [markdown]
# # JSON

# %%
df1 = pd.DataFrame(
    [["a", "b"], ["c", "d"]], index=["row1", "row2"], columns=["col1", "col2"]
)

print(df1)
# Out:
#      col1 col2
# row1    a    b
# row2    c    d

# %%
df1.to_json(orient="index")
# Out:
# '{"row1":{"col1":"a","col2":"b"},"row2":{"col1":"c","col2":"d"}}'

# %% [markdown]
# ---

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# AOA  https://www.exchangerate-api.com
# ARS  https://www.exchangerate-api.com
# AUD  https://www.exchangerate-api.com
# AWG  https://www.exchangerate-api.com
# AZN  https://www.exchangerate-api.com
# BAM  https://www.exchangerate-api.com
# BBD  https://www.exchangerate-api.com
# BDT  https://www.exchangerate-api.com
# BGN  https://www.exchangerate-api.com
# BHD  https://www.exchangerate-api.com
# BIF  https://www.exchangerate-api.com
# BMD  https://www.exchangerate-api.com
# BND  https://www.exchangerate-api.com
# BOB  https://www.exchangerate-api.com
# BRL  https://www.exchangerate-api.com
# BSD  https://www.exchangerate-api.com
# BTN  https://www.exchangerate-api.com
# BWP  https://www.exchangerate-api.com
# ...

# %%
df2 = pd.read_json("https://jsonplaceholder.typicode.com/comments")
df2.head()
# Out:
#    postId  id                                       name  \
# 0       1   1               id labore ex et quam laborum
# 1       1   2  quo vero reiciendis velit similique earum
# 2       1   3              odio adipisci rerum aut animi
# 3       1   4                             alias odio sit
# 4       1   5      vero eaque aliquid doloribus et culpa
#
#                     email                                               body
# 0      Eliseo@gardner.biz  laudantium enim quasi est quidem magnam volupt...
# 1  Jayne_Kuhic@sydney.com  est natus enim nihil est dolore omnis voluptat...
# 2     Nikita@garfield.biz  quia molestiae reprehenderit quasi aspernatur\...
# 3           Lew@alysha.tv  non et atque\noccaecati deserunt quas accusant...
# 4       Hayden@althea.biz  harum non quasi et ratione\ntempore iure ex vo...
